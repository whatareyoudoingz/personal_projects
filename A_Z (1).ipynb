# %%
# !pip install icrawler
# Out:
# Collecting icrawler
#   Downloading icrawler-0.6.7-py3-none-any.whl (34 kB)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from icrawler) (6.0.1)
# Installing collected packages: icrawler
# Successfully installed icrawler-0.6.7

# %%
from google.colab import drive
drive.mount('/content/drive')
import os
#import icrawler
import datetime
from multiprocessing import Pool
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # 데이터 크롤링 & 라벨링
# - 타깃 클래스 3개 : 종이 가방, 패트 병, 비닐 봉지
# - https://icrawler.readthedocs.io/en/latest/builtin.html#search-engine-crawlers
# - https://inhovation97.tistory.com/36

# %% [markdown]
# ### train,valid,test 폴더 생성

# %%
for x in ['train_data1','valid_data1','test_data1']:
  add='/content/drive/MyDrive/recycle/'+x
  os.mkdir(add)

# %% [markdown]
# ### 폴더에 이미지 저장 & 라벨링

# %%
from icrawler.builtin import GoogleImageCrawler
import glob

# %%
keywords=['plastic bag','paper bag','pet bottle']
path='/content/drive/MyDrive/recycle/train_data1'
for i in keywords:
  # 폴더 안에 이미지 삽입
  path1=path+'/'+i
  os.mkdir(path1)
  google_crawler = GoogleImageCrawler(
      feeder_threads=1,
      parser_threads=1,
      downloader_threads=4,
      storage={'root_dir': path1 })
  filters = dict(
      size='large',
      color='orange',
      license='commercial,modify',
      date=((2020, 11, 30), (2022, 11, 30)))
  google_crawler.crawl(keyword=i, filters=filters, offset=0, max_num=1000,
                      min_size=(200,200), max_size=None, file_idx_offset=0)
  path2=path1+'/*'
  image=glob.glob(path2)
  for x,y in enumerate(image):
    os.rename(y,os.path.join(path1+"/",f"{i}_"+"{0:06d}".format(x+1)+"."+y[-3:]))
    #if 'plastic bag' not in y and 'paper bag' not in y and 'pet bottle' not in y:
      #os.rename(y,os.path.join(path+"/",f"{i}_"+"{0:06d}".format(x+1)+"."+y[-3:]))
# Out:
# ERROR:downloader:Response status code 404, file https://www.goodfreephotos.com/food/basket-of-pub-chips-with-sauce.jpg
# ERROR:downloader:Response status code 404, file https://upload.wikimedia.org/wikipedia/commons/thumb/a/af/Chipotle_Cultivating_Thought.jpg
# ERROR:downloader:Response status code 404, file https://upload.wikimedia.org/wikipedia/commons/thumb/f/f1/MC_%E6%BE%B3%E9%96%80%E5%8D%8A%E5%B3%B6_Macau_Peninsula_tour_%E6%9C%80%E9%A6%99%E9%A4%85%E5%AE%B6_Pastelaria_Chui_Heong_yellow_plastic_shopping_bag_November_2019_SS2.jpg
# ERROR:downloader:Response status code 404, file https://upload.wikimedia.org/wikipedia/commons/thumb/a/af/Chipotle_Cultivating_Thought.jpg
# ERROR:downloader:Response status code 404, file https://upload.wikimedia.org/wikipedia/commons/thumb/0/0b/C1000_Winschoten_%26_C1000_large_shopping_bags%2C_Groningen_%282019%29_06.jpg
# ERROR:downloader:Response status code 404, file https://upload.wikimedia.org/wikipedia/commons/thumb/3/3d/Fish-and-chips-in-a-paper-bag.jpg
# ERROR:downloader:Response status code 404, file https://upload.wikimedia.org/wikipedia/commons/thumb/a/a2/Box%2C_hat_%28AM_2015.51.30-6%29.jpg
# ERROR:downloader:Response status code 404, file https://upload.wikimedia.org/wikipedia/commons/thumb/5/56/Un_chat_qui_joue_avec_un_sac_Franprix_%28mai_2022%29.jpg
# ERROR:downloader:Response status code 404, file https://upload.wikimedia.org/wikipedia/commons/thumb/9/93/Man_holding_safety_orange_paper.jpg
# ERROR:downloader:Response status code 404, file https://upload.wikimedia.org/wikipedia/commons/thumb/9/93/Recyclable_finnish_plastic_bottles_with_deposit.jpg
# ERROR:downloader:Response status code 404, file https://upload.wikimedia.org/wikipedia/commons/thumb/e/e5/Erd%C3%A9ly%2C_Pongr%C3%A1c-h%C3%A1g%C3%B3%2C_feny%C5%91_sz%C3%B6rp.jpg
# ERROR:downloader:Response status code 404, file https://www.goodfreephotos.com/other-photos/flame-in-a-bottle.jpg
# ERROR:downloader:Response status code 403, file https://img.rawpixel.com/s3fs-private/rawpixel_images/website_content/sv165278-image-kwvx6syn.jpg

# %%
keywords=['plastic bag','paper bag','pet bottle']
path='/content/drive/MyDrive/recycle/valid_data1'
for i in keywords:
  # 폴더 안에 이미지 삽입
  path1=path+'/'+i
  os.mkdir(path1)
  google_crawler = GoogleImageCrawler(
      feeder_threads=1,
      parser_threads=1,
      downloader_threads=4,
      storage={'root_dir': path1 })
  filters = dict(
      size='large',
      color='orange',
      license='commercial,modify',
      date=((2019, 11, 30), (2020, 11, 30)))
  google_crawler.crawl(keyword=i, filters=filters, offset=0, max_num=1000,
                      min_size=(200,200), max_size=None, file_idx_offset=0)
  path2=path1+'/*'
  image=glob.glob(path2)
  for x,y in enumerate(image):
    os.rename(y,os.path.join(path1+"/",f"{i}_"+"{0:06d}".format(x+1)+"."+y[-3:]))
# Out:
# ERROR:downloader:Response status code 404, file https://www.goodfreephotos.com/food/basket-of-pub-chips-with-sauce.jpg
# ERROR:downloader:Response status code 404, file https://upload.wikimedia.org/wikipedia/commons/thumb/a/af/Chipotle_Cultivating_Thought.jpg
# ERROR:downloader:Response status code 404, file https://upload.wikimedia.org/wikipedia/commons/thumb/f/f1/MC_%E6%BE%B3%E9%96%80%E5%8D%8A%E5%B3%B6_Macau_Peninsula_tour_%E6%9C%80%E9%A6%99%E9%A4%85%E5%AE%B6_Pastelaria_Chui_Heong_yellow_plastic_shopping_bag_November_2019_SS2.jpg
# ERROR:downloader:Response status code 404, file https://upload.wikimedia.org/wikipedia/commons/thumb/a/af/Chipotle_Cultivating_Thought.jpg
# ERROR:downloader:Response status code 404, file https://upload.wikimedia.org/wikipedia/commons/thumb/0/0b/C1000_Winschoten_%26_C1000_large_shopping_bags%2C_Groningen_%282019%29_06.jpg
# ERROR:downloader:Response status code 404, file https://upload.wikimedia.org/wikipedia/commons/thumb/3/3d/Fish-and-chips-in-a-paper-bag.jpg
# ERROR:downloader:Response status code 404, file https://upload.wikimedia.org/wikipedia/commons/thumb/5/56/Un_chat_qui_joue_avec_un_sac_Franprix_%28mai_2022%29.jpg
# ERROR:downloader:Response status code 404, file https://upload.wikimedia.org/wikipedia/commons/thumb/9/93/Man_holding_safety_orange_paper.jpg
# ERROR:downloader:Response status code 404, file https://upload.wikimedia.org/wikipedia/commons/thumb/9/93/Recyclable_finnish_plastic_bottles_with_deposit.jpg
# ERROR:downloader:Response status code 404, file https://upload.wikimedia.org/wikipedia/commons/thumb/e/e5/Erd%C3%A9ly%2C_Pongr%C3%A1c-h%C3%A1g%C3%B3%2C_feny%C5%91_sz%C3%B6rp.jpg
# ERROR:downloader:Response status code 404, file https://www.goodfreephotos.com/other-photos/flame-in-a-bottle.jpg
# ERROR:downloader:Response status code 404, file https://upload.wikimedia.org/wikipedia/commons/thumb/2/23/Guaran%C3%A1_Per%C3%BA_ediciones.jpg

# %%
keywords=['plastic bag','paper bag','pet bottle']
path='/content/drive/MyDrive/recycle/test_data1'
for i in keywords:
  # 폴더 안에 이미지 삽입
  path1=path+'/'+i
  os.mkdir(path1)
  google_crawler = GoogleImageCrawler(
      feeder_threads=1,
      parser_threads=1,
      downloader_threads=4,
      storage={'root_dir': path1 })
  filters = dict(
      size='large',
      color='orange',
      license='commercial,modify',
      date=((2018, 11, 30), (2019, 11, 30)))
  google_crawler.crawl(keyword=i, filters=filters, offset=0, max_num=1000,
                      min_size=(200,200), max_size=None, file_idx_offset=0)
  path2=path1+'/*'
  image=glob.glob(path2)
  for x,y in enumerate(image):
    os.rename(y,os.path.join(path1+"/",f"{i}_"+"{0:06d}".format(x+1)+"."+y[-3:]))
# Out:
# ERROR:downloader:Response status code 404, file https://www.goodfreephotos.com/food/basket-of-pub-chips-with-sauce.jpg
# ERROR:downloader:Response status code 404, file https://upload.wikimedia.org/wikipedia/commons/thumb/a/af/Chipotle_Cultivating_Thought.jpg
# ERROR:downloader:Response status code 404, file https://upload.wikimedia.org/wikipedia/commons/thumb/f/f1/MC_%E6%BE%B3%E9%96%80%E5%8D%8A%E5%B3%B6_Macau_Peninsula_tour_%E6%9C%80%E9%A6%99%E9%A4%85%E5%AE%B6_Pastelaria_Chui_Heong_yellow_plastic_shopping_bag_November_2019_SS2.jpg
# ERROR:downloader:Response status code 404, file https://upload.wikimedia.org/wikipedia/commons/thumb/a/af/Chipotle_Cultivating_Thought.jpg
# ERROR:downloader:Response status code 404, file https://upload.wikimedia.org/wikipedia/commons/thumb/0/0b/C1000_Winschoten_%26_C1000_large_shopping_bags%2C_Groningen_%282019%29_06.jpg
# ERROR:downloader:Response status code 404, file https://upload.wikimedia.org/wikipedia/commons/thumb/3/3d/Fish-and-chips-in-a-paper-bag.jpg
# ERROR:downloader:Response status code 404, file https://upload.wikimedia.org/wikipedia/commons/thumb/a/a2/Box%2C_hat_%28AM_2015.51.30-6%29.jpg
# ERROR:downloader:Response status code 404, file https://upload.wikimedia.org/wikipedia/commons/thumb/5/56/Un_chat_qui_joue_avec_un_sac_Franprix_%28mai_2022%29.jpg
# ERROR:downloader:Response status code 404, file https://upload.wikimedia.org/wikipedia/commons/thumb/9/93/Man_holding_safety_orange_paper.jpg
# ERROR:downloader:Response status code 404, file https://upload.wikimedia.org/wikipedia/commons/thumb/9/93/Recyclable_finnish_plastic_bottles_with_deposit.jpg
# ERROR:downloader:Response status code 404, file https://upload.wikimedia.org/wikipedia/commons/thumb/e/e5/Erd%C3%A9ly%2C_Pongr%C3%A1c-h%C3%A1g%C3%B3%2C_feny%C5%91_sz%C3%B6rp.jpg
# ERROR:downloader:Response status code 404, file https://www.goodfreephotos.com/other-photos/flame-in-a-bottle.jpg
# ERROR:downloader:Response status code 404, file https://upload.wikimedia.org/wikipedia/commons/thumb/2/23/Guaran%C3%A1_Per%C3%BA_ediciones.jpg
# ERROR:downloader:Response status code 403, file https://img.rawpixel.com/s3fs-private/rawpixel_images/website_content/sv165278-image-kwvx6syn.jpg

# %% [markdown]
# # 모델 구성

# %%
import pathlib
from tensorflow.keras.utils import image_dataset_from_directory
base_dir = pathlib.Path("/content/drive/MyDrive/recycle/")
train_dataset = image_dataset_from_directory( #각 32개 데이터 + 32개 라벨 묶음
    base_dir/'train_data1' ,
    image_size=(224, 224),
    batch_size=32)
valid_dataset = image_dataset_from_directory( #각 32개 데이터 + 32개 라벨 묶음
    base_dir/'valid_data1' ,
    image_size=(224, 224),
    batch_size=32)
test_dataset = image_dataset_from_directory( #각 32개 데이터 + 32개 라벨 묶음
    base_dir/'test_data1' ,
    image_size=(224, 224),
    batch_size=32)
# Out:
# Found 228 files belonging to 3 classes.
# Found 230 files belonging to 3 classes.
# Found 237 files belonging to 3 classes.

# %%
for images, labels in train_dataset:
    print(labels)
# Out:
# tf.Tensor([0 1 2 2 2 1 0 2 2 2 0 1 2 1 1 1 1 0 1 0 1 2 1 1 2 0 0 0 2 1 0 0], shape=(32,), dtype=int32)
# tf.Tensor([2 1 0 0 0 2 1 1 0 2 1 2 1 0 1 0 2 0 2 0 2 1 2 0 0 1 1 0 2 0 1 0], shape=(32,), dtype=int32)
# tf.Tensor([2 2 2 2 0 2 2 2 0 1 0 2 2 1 1 0 2 1 2 2 0 2 0 2 1 2 1 1 1 2 1 2], shape=(32,), dtype=int32)
# tf.Tensor([2 0 1 1 2 2 0 2 0 2 1 0 0 1 2 2 2 1 1 1 0 1 1 1 2 0 0 0 2 2 0 2], shape=(32,), dtype=int32)
# tf.Tensor([1 1 1 0 0 0 0 2 0 0 1 2 2 1 2 2 1 2 1 0 2 0 1 0 1 0 1 0 1 2 2 0], shape=(32,), dtype=int32)
# tf.Tensor([0 1 0 0 2 2 0 2 2 2 0 0 1 0 0 1 1 1 1 2 0 0 1 1 2 0 2 2 2 0 1 0], shape=(32,), dtype=int32)
# tf.Tensor([0 1 0 2 2 2 2 2 2 0 0 0 2 1 2 2 1 1 0 0 1 0 1 1 2 1 2 1 0 1 0 0], shape=(32,), dtype=int32)
# tf.Tensor([0 0 2 2], shape=(4,), dtype=int32)

# %%
from tensorflow import keras
from keras import layers
from keras.layers import Flatten, Dense, Dropout

data_augmentation = keras.Sequential( #데이터 증강층
    [layers.RandomFlip("horizontal"), #좌우 대칭
     layers.RandomRotation(0.1), #시계방향으로 36도, -36도
     layers.RandomZoom(0.2)])

conv_base = keras.applications.vgg16.VGG16(
    include_top=False,
    input_shape=(224, 224, 3))
conv_base.trainable = False #특성추출층 파라미터 동결

inputs = keras.Input(shape=(224, 224, 3))
x = data_augmentation(inputs) #데이터 증강층
x = keras.applications.vgg16.preprocess_input(x) #데이터 전처리층
x = conv_base(x) #데이터 특성추출기 층
#새로운 분류층 생성
x = Flatten()(x)
x = Dense(256)(x)
x = Dropout(0.5)(x)
outputs = Dense(3, activation="softmax")(x)
#모델 생성
model = keras.Model(inputs, outputs)
model.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  sequential_3 (Sequential)   (None, 224, 224, 3)       0
#
#  tf.__operators__.getitem_2  (None, 224, 224, 3)       0
#   (SlicingOpLambda)
#
#  tf.nn.bias_add_2 (TFOpLamb  (None, 224, 224, 3)       0
#  da)
#
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  flatten_2 (Flatten)         (None, 25088)             0
#
#  dense_4 (Dense)             (None, 256)               6422784
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_5 (Dense)             (None, 3)                 771
#
# =================================================================
# Total params: 21138243 (80.64 MB)
# Trainable params: 6423555 (24.50 MB)
# Non-trainable params: 14714688 (56.13 MB)
# _________________________________________________________________

# %%
model.compile(loss="sparse_categorical_crossentropy",
              optimizer="rmsprop",
              metrics=["accuracy"])

callbacks = [keras.callbacks.ModelCheckpoint(
      filepath="feature_extraction.x",
      save_best_only=True,
      monitor="val_loss")]

history = model.fit(
    train_dataset,
    epochs=50,
    validation_data=valid_dataset,
    callbacks=callbacks)
# Out:
# Epoch 1/50
# 8/8 [==============================] - 27s 2s/step - loss: 118.7066 - accuracy: 0.7325 - val_loss: 135.9716 - val_accuracy: 0.7391
# Epoch 2/50
# 8/8 [==============================] - 25s 2s/step - loss: 67.4940 - accuracy: 0.7851 - val_loss: 66.2833 - val_accuracy: 0.8522
# Epoch 3/50
# 8/8 [==============================] - 21s 2s/step - loss: 60.8209 - accuracy: 0.8070 - val_loss: 75.9360 - val_accuracy: 0.8174
# Epoch 4/50
# 8/8 [==============================] - 28s 3s/step - loss: 56.2470 - accuracy: 0.8158 - val_loss: 49.7876 - val_accuracy: 0.8609
# Epoch 5/50
# 8/8 [==============================] - 35s 3s/step - loss: 48.8880 - accuracy: 0.7982 - val_loss: 56.9129 - val_accuracy: 0.8565
# Epoch 6/50
# 8/8 [==============================] - 20s 2s/step - loss: 52.7179 - accuracy: 0.8202 - val_loss: 58.9609 - val_accuracy: 0.8652
# Epoch 7/50
# 8/8 [==============================] - 23s 2s/step - loss: 65.2152 - accuracy: 0.8158 - val_loss: 59.0590 - val_accuracy: 0.8739
# Epoch 8/50
# 8/8 [==============================] - 20s 2s/step - loss: 66.7765 - accuracy: 0.7939 - val_loss: 68.6668 - val_accuracy: 0.8435
# Epoch 9/50
# 8/8 [==============================] - 25s 2s/step - loss: 47.6690 - accuracy: 0.8246 - val_loss: 45.9028 - val_accuracy: 0.8783
# Epoch 10/50
# 8/8 [==============================] - 31s 3s/step - loss: 53.7500 - accuracy: 0.8114 - val_loss: 78.8634 - val_accuracy: 0.7739
# Epoch 11/50
# 8/8 [==============================] - 22s 2s/step - loss: 47.2951 - accuracy: 0.8509 - val_loss: 50.8679 - val_accuracy: 0.8652
# Epoch 12/50
# 8/8 [==============================] - 21s 2s/step - loss: 51.7485 - accuracy: 0.8377 - val_loss: 86.7655 - val_accuracy: 0.8043
# Epoch 13/50
# 8/8 [==============================] - 21s 2s/step - loss: 36.1749 - accuracy: 0.8816 - val_loss: 52.3230 - val_accuracy: 0.8826
# Epoch 14/50
# 8/8 [==============================] - 27s 2s/step - loss: 47.0168 - accuracy: 0.8553 - val_loss: 35.2334 - val_accuracy: 0.8652
# Epoch 15/50
# 8/8 [==============================] - 31s 3s/step - loss: 41.9618 - accuracy: 0.8509 - val_loss: 44.2132 - val_accuracy: 0.8739
# Epoch 16/50
# 8/8 [==============================] - 22s 2s/step - loss: 37.6883 - accuracy: 0.8772 - val_loss: 60.5076 - val_accuracy: 0.8609
# Epoch 17/50
# 8/8 [==============================] - 20s 2s/step - loss: 46.1422 - accuracy: 0.8333 - val_loss: 44.7961 - val_accuracy: 0.8652
# Epoch 18/50
# 8/8 [==============================] - 22s 2s/step - loss: 44.0201 - accuracy: 0.8509 - val_loss: 44.2305 - val_accuracy: 0.8652
# Epoch 19/50
# 8/8 [==============================] - 22s 2s/step - loss: 40.6996 - accuracy: 0.8553 - val_loss: 46.6939 - val_accuracy: 0.8696
# Epoch 20/50
# 8/8 [==============================] - 23s 2s/step - loss: 36.2871 - accuracy: 0.8728 - val_loss: 37.0165 - val_accuracy: 0.8783
# Epoch 21/50
# 8/8 [==============================] - 21s 2s/step - loss: 48.6366 - accuracy: 0.8509 - val_loss: 71.5035 - val_accuracy: 0.7870
# Epoch 22/50
# 8/8 [==============================] - 35s 4s/step - loss: 38.9453 - accuracy: 0.8465 - val_loss: 29.0930 - val_accuracy: 0.8826
# Epoch 23/50
# 8/8 [==============================] - 21s 2s/step - loss: 43.2242 - accuracy: 0.8596 - val_loss: 42.3991 - val_accuracy: 0.8826
# Epoch 24/50
# 8/8 [==============================] - 20s 2s/step - loss: 56.3080 - accuracy: 0.8553 - val_loss: 46.4748 - val_accuracy: 0.8696
# Epoch 25/50
# 8/8 [==============================] - 31s 3s/step - loss: 39.5529 - accuracy: 0.8114 - val_loss: 43.0795 - val_accuracy: 0.8783
# Epoch 26/50
# 8/8 [==============================] - 22s 2s/step - loss: 51.3811 - accuracy: 0.8553 - val_loss: 36.9755 - val_accuracy: 0.8870
# Epoch 27/50
# 8/8 [==============================] - 21s 2s/step - loss: 47.0996 - accuracy: 0.8509 - val_loss: 36.4149 - val_accuracy: 0.8696
# Epoch 28/50
# 8/8 [==============================] - 22s 2s/step - loss: 52.6572 - accuracy: 0.8202 - val_loss: 32.9698 - val_accuracy: 0.8739
# Epoch 29/50
# 8/8 [==============================] - 20s 2s/step - loss: 36.1690 - accuracy: 0.8509 - val_loss: 32.0009 - val_accuracy: 0.8870
# Epoch 30/50
# 8/8 [==============================] - 22s 2s/step - loss: 41.3808 - accuracy: 0.8465 - val_loss: 29.6698 - val_accuracy: 0.8826
# Epoch 31/50
# 8/8 [==============================] - 21s 2s/step - loss: 33.7831 - accuracy: 0.8333 - val_loss: 51.9259 - val_accuracy: 0.8174
# Epoch 32/50
# 8/8 [==============================] - 22s 2s/step - loss: 35.2538 - accuracy: 0.8640 - val_loss: 40.0117 - val_accuracy: 0.8652
# Epoch 33/50
# 8/8 [==============================] - 23s 2s/step - loss: 39.3038 - accuracy: 0.8158 - val_loss: 24.5420 - val_accuracy: 0.8870
# Epoch 34/50
# 8/8 [==============================] - 21s 2s/step - loss: 31.1746 - accuracy: 0.8596 - val_loss: 67.9560 - val_accuracy: 0.7783
# Epoch 35/50
# 8/8 [==============================] - 20s 2s/step - loss: 36.6356 - accuracy: 0.8377 - val_loss: 40.4188 - val_accuracy: 0.8826
# Epoch 36/50
# 8/8 [==============================] - 22s 2s/step - loss: 33.3687 - accuracy: 0.8640 - val_loss: 38.4824 - val_accuracy: 0.8609
# Epoch 37/50
# 8/8 [==============================] - 20s 2s/step - loss: 34.1125 - accuracy: 0.8509 - val_loss: 43.7852 - val_accuracy: 0.8783
# Epoch 38/50
# 8/8 [==============================] - 21s 2s/step - loss: 25.1042 - accuracy: 0.8728 - val_loss: 41.9193 - val_accuracy: 0.8609
# Epoch 39/50
# 8/8 [==============================] - 26s 2s/step - loss: 37.0696 - accuracy: 0.8684 - val_loss: 22.1026 - val_accuracy: 0.8826
# Epoch 40/50
# 8/8 [==============================] - 22s 2s/step - loss: 46.0609 - accuracy: 0.8377 - val_loss: 25.5127 - val_accuracy: 0.8826
# Epoch 41/50
# 8/8 [==============================] - 20s 2s/step - loss: 43.2460 - accuracy: 0.8158 - val_loss: 43.7919 - val_accuracy: 0.8565
# Epoch 42/50
# 8/8 [==============================] - 24s 2s/step - loss: 27.0357 - accuracy: 0.8772 - val_loss: 35.3356 - val_accuracy: 0.8826
# Epoch 43/50
# 8/8 [==============================] - 20s 2s/step - loss: 23.2696 - accuracy: 0.8772 - val_loss: 32.5437 - val_accuracy: 0.8826
# Epoch 44/50
# 8/8 [==============================] - 22s 2s/step - loss: 30.7364 - accuracy: 0.8684 - val_loss: 24.2114 - val_accuracy: 0.8826
# Epoch 45/50
# 8/8 [==============================] - 20s 2s/step - loss: 30.8244 - accuracy: 0.8289 - val_loss: 23.5005 - val_accuracy: 0.8870
# Epoch 46/50
# 8/8 [==============================] - 22s 2s/step - loss: 24.6596 - accuracy: 0.8772 - val_loss: 22.1502 - val_accuracy: 0.8826
# Epoch 47/50
# 8/8 [==============================] - 22s 2s/step - loss: 33.0506 - accuracy: 0.8553 - val_loss: 34.7452 - val_accuracy: 0.8478
# Epoch 48/50
# 8/8 [==============================] - 20s 2s/step - loss: 21.8827 - accuracy: 0.8816 - val_loss: 28.8451 - val_accuracy: 0.8826
# Epoch 49/50
# 8/8 [==============================] - 22s 2s/step - loss: 27.5767 - accuracy: 0.8684 - val_loss: 26.2134 - val_accuracy: 0.8783
# Epoch 50/50
# 8/8 [==============================] - 21s 2s/step - loss: 26.9755 - accuracy: 0.8640 - val_loss: 28.4366 - val_accuracy: 0.8870

# %% [markdown]
# # 정확도 측정

# %%
# 테스트 데이터셋을 사용하여 모델 평가
test_loss, test_accuracy = model.evaluate(test_dataset)

# 정확도 출력
print(f"테스트 데이터셋 정확도: {test_accuracy * 100:.2f}%")
# Out:
# 8/8 [==============================] - 13s 447ms/step - loss: 27.5967 - accuracy: 0.8903
# 테스트 데이터셋 정확도: 89.03%

# %% [markdown]
# # 시각화 검증

# %%
from tensorflow.keras.preprocessing import image
import numpy as np

# 이미지 파일 경로 설정
image_path = '/content/drive/MyDrive/recycle/test_data1/pet bottle/pet bottle_000004.jpg'  # 이미지 파일의 경로를 설정합니다.

# 이미지를 불러오고 전처리
img = image.load_img(image_path, target_size=(224, 224))  # 이미지 크기를 모델의 입력 크기로 조정
img = image.img_to_array(img)  # 이미지를 넘파이 배열로 변환
# 시각화를 위한 것
imgs = img / 255.0  # 이미지의 픽셀 값을 [0, 1] 범위로 조정
imgs = np.expand_dims(imgs, axis=0)  # 배치 차원을 추가 (1개의 이미지)

# 이미지를 모델에 전달하기 위한 전처리 (VGG16의 preprocess_input 함수 사용)
from tensorflow.keras.applications.vgg16 import preprocess_input
img = np.expand_dims(img, axis=0)  # 배치 차원을 추가 (1개의 이미지)
img = preprocess_input(img)

import matplotlib.pyplot as plt

# 모델에 이미지 입력하여 결과 출력
result = model.predict(img)

# 클래스 이름 정의 (모델의 클래스에 맞게 설정)
class_names = ['paper bag', 'pet bottle','plastic bag']

# 이미지 시각화
plt.imshow(imgs[0])  # 전처리 반대 작업 (VGG16 모델의 preprocess_input 역전처리)
plt.title(f'Predicted: {class_names[np.argmax(result)]}')
plt.axis('off')
plt.show()
# Out:
# 1/1 [==============================] - 0s 31ms/step

# %%
import os

# plastic bag 이미지 파일 경로 설정
plastic_bag_dir = '/content/drive/MyDrive/recycle/train_data1/paper bag'
class_names = ['paper bag', 'pet bottle','plastic bag']
plastic_bag_images = [os.path.join(plastic_bag_dir, img) for img in os.listdir(plastic_bag_dir)[:15]]

# 이미지를 시각화
plt.figure(figsize=(15, 10))
for i, image_path in enumerate(plastic_bag_images):
    img = image.load_img(image_path, target_size=(224, 224))
    img = image.img_to_array(img)
    imgs = img / 255.0  # 이미지의 픽셀 값을 [0, 1] 범위로 조정
    imgs = np.expand_dims(imgs, axis=0)  # 배치 차원을 추가 (1개의 이미지)

    img = np.expand_dims(img, axis=0)  # 배치 차원을 추가 (1개의 이미지)
    img = preprocess_input(img)

    result = model.predict(img)
    plt.subplot(3, 5, i + 1)
    plt.imshow(imgs[0])
    plt.title(f'Predicted: {class_names[np.argmax(result)]}')
    plt.axis('off')

plt.show()
# Out:
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step

# %%
for x in ['train_data1','valid_data1','test_data1']:
  add='/content/drive/MyDrive/recycle/'+x
  os.rmdir(add)
